# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("HR_comma_sep.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_salary=LabelEncoder()
inputs=df.drop(['last_evaluation','number_project','time_spend_company','Work_accident','Department'],axis='columns')
inputs.head()
# Out:
#    satisfaction_level  average_montly_hours  left  promotion_last_5years  \
# 0                0.38                   157     1                      0
# 1                0.80                   262     1                      0
# 2                0.11                   272     1                      0
# 3                0.72                   223     1                      0
# 4                0.37                   159     1                      0
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
inputs['salary_n']= le_salary.fit_transform(inputs['salary'])
inputs.head()
# Out:
#    satisfaction_level  average_montly_hours  left  promotion_last_5years  \
# 0                0.38                   157     1                      0
# 1                0.80                   262     1                      0
# 2                0.11                   272     1                      0
# 3                0.72                   223     1                      0
# 4                0.37                   159     1                      0
#
#    salary  salary_n
# 0     low         1
# 1  medium         2
# 2  medium         2
# 3     low         1
# 4     low         1

# %%
inputs_n=inputs.drop('salary',axis='columns')
inputs_n.head()
# Out:
#    satisfaction_level  average_montly_hours  left  promotion_last_5years  \
# 0                0.38                   157     1                      0
# 1                0.80                   262     1                      0
# 2                0.11                   272     1                      0
# 3                0.72                   223     1                      0
# 4                0.37                   159     1                      0
#
#    salary_n
# 0         1
# 1         2
# 2         2
# 3         1
# 4         1

# %%
X=inputs_n
X
# Out:
#        satisfaction_level  average_montly_hours  left  promotion_last_5years  \
# 0                    0.38                   157     1                      0
# 1                    0.80                   262     1                      0
# 2                    0.11                   272     1                      0
# 3                    0.72                   223     1                      0
# 4                    0.37                   159     1                      0
# ...                   ...                   ...   ...                    ...
# 14994                0.40                   151     1                      0
# 14995                0.37                   160     1                      0
# 14996                0.37                   143     1                      0
# 14997                0.11                   280     1                      0
# 14998                0.37                   158     1                      0
#
#        salary_n
# 0             1
# 1             2
# 2             2
# 3             1
# 4             1
# ...         ...
# 14994         1
# 14995         1
# 14996         1
# 14997         1
# 14998         1
#
# [14999 rows x 5 columns]

# %%
y=df.left
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: left, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=0.1)

# %%
len(X_train)
# Out:
# 13499

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
model.score(X_test,y_test)
# Out:
# 1.0
